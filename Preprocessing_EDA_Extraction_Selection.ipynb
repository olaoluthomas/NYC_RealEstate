# %%
import pandas as pd
import numpy as np

# %%
bronx = pd.read_csv('bronx.csv')

# %%
bronx.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-eb9d8c6a46d5> in <module>()
# ----> 1 bronx.head()
#
# NameError: name 'bronx' is not defined

# %%
bronx.tail()
# Out:
#                         address   area  baths  beds building type   latitude  \
# 12671  4970 Independence Avenue    NaN    4.0   8.0         House  40.898399
# 12672   4455 Douglas Avenue #8C  919.0    1.0   1.0         Condo  40.889400
# 12673                       NaN    NaN    NaN   NaN           NaN        NaN
# 12674                       NaN    NaN    NaN   NaN           NaN        NaN
# 12675                       NaN    NaN    NaN   NaN           NaN        NaN
#
#        longitude neighborhood      price
# 12671 -73.910599    Riverdale  3490000.0
# 12672 -73.917503    Riverdale   460000.0
# 12673        NaN          NaN        NaN
# 12674        NaN          NaN        NaN
# 12675        NaN          NaN        NaN

# %%
bronx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12676 entries, 0 to 12675
# Data columns (total 9 columns):
# address          12613 non-null object
# area             8267 non-null float64
# baths            11685 non-null float64
# beds             12004 non-null float64
# building type    12576 non-null object
# latitude         12610 non-null float64
# longitude        12610 non-null float64
# neighborhood     12576 non-null object
# price            12612 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 891.4+ KB

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
bronx.hist(bins=50, figsize=(20,15))
plt.show()

# %%
bronx.plot(kind="scatter", x='longitude', y='latitude')

# %%
bronx_clean = bronx.dropna(how='any')

# %%
bronx_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7440 entries, 1 to 12672
# Data columns (total 9 columns):
# address          7440 non-null object
# area             7440 non-null float64
# baths            7440 non-null float64
# beds             7440 non-null float64
# building type    7440 non-null object
# latitude         7440 non-null float64
# longitude        7440 non-null float64
# neighborhood     7440 non-null object
# price            7440 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 581.2+ KB

# %%
bronx_clean.plot(kind="scatter", x='longitude', y='latitude')

# %%
bronx_clean[bronx_clean['latitude'] < 40].index
# Out:
# Int64Index([], dtype='int64')

# %%
bronx_clean = bronx_clean.drop(bronx_clean[bronx_clean['latitude'] < 40].index).reset_index()

# %%
bronx_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7427 entries, 0 to 7426
# Data columns (total 10 columns):
# index            7427 non-null int64
# address          7427 non-null object
# area             7427 non-null float64
# baths            7427 non-null float64
# beds             7427 non-null float64
# building type    7427 non-null object
# latitude         7427 non-null float64
# longitude        7427 non-null float64
# neighborhood     7427 non-null object
# price            7427 non-null float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 580.3+ KB

# %%
bronx_clean.plot(kind="scatter", x='longitude', y='latitude')

# %%
bronx_clean = bronx_clean.drop('index', axis=1)

# %%
bronx_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7427 entries, 0 to 7426
# Data columns (total 9 columns):
# address          7427 non-null object
# area             7427 non-null float64
# baths            7427 non-null float64
# beds             7427 non-null float64
# building type    7427 non-null object
# latitude         7427 non-null float64
# longitude        7427 non-null float64
# neighborhood     7427 non-null object
# price            7427 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 522.3+ KB

# %%
bronx_clean[bronx_clean['longitude'] < -75].index
# Out:
# Int64Index([4501, 4834, 5194], dtype='int64')

# %%
bronx_clean[bronx_clean['longitude'] > -73].index
# Out:
# Int64Index([2777], dtype='int64')

# %%
bronx_clean[2777:2778]
# Out:
#                       address    area  baths  beds building type   latitude  \
# 2777  83 Spring Close Highway  2750.0    2.0   3.0         House  40.972599
#
#       longitude        neighborhood      price
# 2777 -72.168701  East Hampton North  1995000.0

# %%
bronx_clean = bronx_clean.drop(bronx_clean[bronx_clean['longitude'] < -75].index)

# %%
bronx_clean = bronx_clean.drop(bronx_clean[bronx_clean['longitude'] > -73].index)

# %%
bronx_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7423 entries, 0 to 7426
# Data columns (total 9 columns):
# address          7423 non-null object
# area             7423 non-null float64
# baths            7423 non-null float64
# beds             7423 non-null float64
# building type    7423 non-null object
# latitude         7423 non-null float64
# longitude        7423 non-null float64
# neighborhood     7423 non-null object
# price            7423 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 579.9+ KB

# %%
bronx_clean.plot(kind="scatter", x='longitude', y='latitude')

# %% [markdown]
# ***This looks like a combination of Queens and Brooklyn and not Bronx***
#
# I have to scrape this again...

# %%
bronx_clean.to_csv('Bronx_P.csv', index=False)

# %%
man = pd.read_csv('Manhattan_Cln.csv')
man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12432 entries, 0 to 12431
# Data columns (total 9 columns):
# address          12331 non-null object
# area             8631 non-null float64
# baths            12051 non-null float64
# beds             11138 non-null float64
# building type    12306 non-null object
# latitude         12331 non-null float64
# longitude        12331 non-null float64
# neighborhood     12306 non-null object
# price            12328 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 874.2+ KB

# %%
man = man.dropna(how='any')

# %%
man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7795 entries, 0 to 12431
# Data columns (total 9 columns):
# address          7795 non-null object
# area             7795 non-null float64
# baths            7795 non-null float64
# beds             7795 non-null float64
# building type    7795 non-null object
# latitude         7795 non-null float64
# longitude        7795 non-null float64
# neighborhood     7795 non-null object
# price            7795 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 609.0+ KB

# %%
man.plot(kind="scatter", x='longitude', y='latitude')

# %%
man = man.drop(man[man['longitude'] > -20].index)

# %%
man.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7777 entries, 0 to 12431
# Data columns (total 9 columns):
# address          7777 non-null object
# area             7777 non-null float64
# baths            7777 non-null float64
# beds             7777 non-null float64
# building type    7777 non-null object
# latitude         7777 non-null float64
# longitude        7777 non-null float64
# neighborhood     7777 non-null object
# price            7777 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 607.6+ KB

# %%
man.plot(kind="scatter", x='longitude', y='latitude')

# %%
man = man.drop(man[man['latitude'] < 40.7].index)
man.plot(kind="scatter", x='longitude', y='latitude')

# %%
man.neighborhood.unique()
# Out:
# array(['Tribeca', 'Lenox Hill', "Hell's Kitchen", 'Murray Hill',
#        'Midtown South', 'Upper East Side', 'East Village',
#        'Lincoln Square', 'Financial District', 'Yorkville', 'Soho',
#        'Midtown', 'Sutton Place', 'Upper West Side', 'Fulton/Seaport',
#        'Manhattan Valley', 'Lower East Side', 'Hudson Heights',
#        'Battery Park City', 'Kips Bay', 'Gramercy Park', 'Inwood',
#        'Greenwich Village', 'Turtle Bay', 'East Harlem', 'Chinatown',
#        'West Chelsea', 'South Harlem', 'West Village', 'Chelsea',
#        'Central Park South', 'Noho', 'Flatiron', 'Central Harlem', 'NoMad',
#        'Hudson Square', 'Morningside Heights', 'Carnegie Hill',
#        'Manhattanville', 'Roosevelt Island', 'Nolita', 'Two Bridges',
#        'Hamilton Heights', 'Hudson Yards', 'Beekman', 'Midtown East',
#        'Fort George', 'Little Italy', 'Washington Heights', 'Civic Center',
#        'Upper Carnegie Hill', 'Manhattan', 'West Harlem'], dtype=object)

# %%
man.to_csv('Man_P.csv', index=False)

# %%
stat = pd.read_csv('staten-island.csv')
stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 9 columns):
# address          374 non-null object
# area             302 non-null float64
# baths            289 non-null float64
# beds             369 non-null float64
# building type    373 non-null object
# latitude         374 non-null float64
# longitude        374 non-null float64
# neighborhood     373 non-null object
# price            374 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 26.6+ KB

# %%
stat = stat.dropna(how='any')
stat.plot(kind="scatter", x='longitude', y='latitude')

# %%
stat = stat.drop(stat[stat['latitude'] < 40.4].index)
stat.plot(kind="scatter", x='longitude', y='latitude')

# %%
stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 0 to 370
# Data columns (total 9 columns):
# address          221 non-null object
# area             221 non-null float64
# baths            221 non-null float64
# beds             221 non-null float64
# building type    221 non-null object
# latitude         221 non-null float64
# longitude        221 non-null float64
# neighborhood     221 non-null object
# price            221 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 17.3+ KB

# %%
stat.to_csv('Staten.csv', index=False)

# %%
staten = pd.read_csv('clean_data/Staten.csv') # I moved it to a folder
staten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221 entries, 0 to 220
# Data columns (total 9 columns):
# address          221 non-null object
# area             221 non-null float64
# baths            221 non-null float64
# beds             221 non-null float64
# building type    221 non-null object
# latitude         221 non-null float64
# longitude        221 non-null float64
# neighborhood     221 non-null object
# price            221 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 15.6+ KB

# %%
staten.neighborhood.unique()
# Out:
# array(['Charleston', 'Saint George', 'New Dorp Beach', 'Huguenot',
#        'Westerleigh', 'Todt Hill', 'Grant City', 'New Brighton',
#        'Port Richmond', 'Mariners Harbor', 'Great Kills', 'New Dorp',
#        'Dongan Hills', 'Emerson Hill', 'Arlington', 'South Beach',
#        'Rosebank', 'Sunnyside (Staten Island)', 'Eltingville', 'Rossville',
#        'Graniteville', 'Pleasant Plains', 'Shore Acres', 'Annadale',
#        'Clifton', 'Midland Beach', 'Bay Terrace', 'Travis', 'Silver Lake',
#        'Tompkinsville', 'New Springville', 'Grasmere', 'Arrochar',
#        'Arden Heights', 'West Brighton', 'Tottenville', 'Meiers Corners',
#        'Staten Island', 'Bulls Head', 'Elm Park', 'Richmondtown',
#        'Port Ivory', 'Egbertville', 'Princes Bay', 'Castleton Corners',
#        'Oakwood', 'Grymes Hill', 'Park Hill', 'Woodrow'], dtype=object)

# %%
br = pd.read_csv('Brooklyn.csv')
br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6356 entries, 0 to 6355
# Data columns (total 9 columns):
# address          6347 non-null object
# area             4752 non-null float64
# baths            6050 non-null float64
# beds             5996 non-null float64
# building type    6325 non-null object
# latitude         6344 non-null float64
# longitude        6344 non-null float64
# neighborhood     6325 non-null object
# price            6346 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 447.0+ KB

# %%
br = br.dropna(how='any')
br.plot(kind="scatter", x='longitude', y='latitude')

# %%
br = br.drop(br[br['latitude'] > 40.75].index)
br.plot(kind="scatter", x='longitude', y='latitude')

# %%
br.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4317 entries, 0 to 6355
# Data columns (total 9 columns):
# address          4317 non-null object
# area             4317 non-null float64
# baths            4317 non-null float64
# beds             4317 non-null float64
# building type    4317 non-null object
# latitude         4317 non-null float64
# longitude        4317 non-null float64
# neighborhood     4317 non-null object
# price            4317 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 337.3+ KB

# %%
br.neighborhood.unique()
# Out:
# array(['Williamsburg', 'Red Hook', 'Ditmas Park', 'Northeast Flatbush',
#        'Flatbush', 'Park Slope', 'Windsor Terrace', 'Bedford-Stuyvesant',
#        'Midwood', 'New Lots', 'Madison', 'Sheepshead Bay', 'Greenwood',
#        'Sunset Park', 'Boerum Hill', 'Greenpoint', 'Canarsie',
#        'Stuyvesant Heights', 'East New York', 'Brownsville', 'Gravesend',
#        'Brighton Beach', 'Coney Island', 'Marine Park',
#        'Prospect Lefferts Gardens', 'Borough Park', 'Downtown Brooklyn',
#        'Bushwick', 'Homecrest', 'Kensington',
#        'Columbia St Waterfront District', 'DUMBO', 'Bensonhurst',
#        'Gerritsen Beach', 'Mapleton', 'Dyker Heights', 'Prospect Heights',
#        'Mill Basin', 'Fort Greene', 'East Williamsburg', 'Ocean Hill',
#        'Crown Heights', 'Manhattan Beach', 'Weeksville',
#        'Brooklyn Heights', 'Carroll Gardens', 'Seagate', 'Cobble Hill',
#        'Fort Hamilton', 'Bath Beach', 'Gowanus', 'Clinton Hill',
# ...

# %% [markdown]
# **The DUMBO neighborhood looks like a fishy entry but turns out to be legit**
#
# EDA very important...

# %%
br.to_csv('Brooklyn_P.csv', index=False)

# %%
que = pd.read_csv('Queens.csv')
que.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11450 entries, 0 to 11449
# Data columns (total 9 columns):
# address          11390 non-null object
# area             7394 non-null float64
# baths            10581 non-null float64
# beds             10842 non-null float64
# building type    11357 non-null object
# latitude         11387 non-null float64
# longitude        11387 non-null float64
# neighborhood     11357 non-null object
# price            11389 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 805.1+ KB

# %%
que = que.dropna(how='any')
que.plot(kind="scatter", x='longitude', y='latitude')

# %%
que = que.drop(que[que['latitude'] < 40.4].index)
que.plot(kind="scatter", x='longitude', y='latitude')

# %%
que = que.drop(que[que['latitude'] > 40.9].index)
que.plot(kind="scatter", x='longitude', y='latitude')

# %% [markdown]
# *The Queens data is clearly showing some parts of Brooklyn*
#
# ***Re-scraping...***

# %%
que = pd.read_csv('Queens.csv')
que.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4914 entries, 0 to 4913
# Data columns (total 9 columns):
# address          4912 non-null object
# area             2533 non-null float64
# baths            4402 non-null float64
# beds             4713 non-null float64
# building type    4900 non-null object
# latitude         4912 non-null float64
# longitude        4912 non-null float64
# neighborhood     4900 non-null object
# price            4912 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 345.6+ KB

# %%
que = que.dropna(how='any')
que.info()
que.plot(kind="scatter", x='longitude', y='latitude')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2243 entries, 0 to 4911
# Data columns (total 9 columns):
# address          2243 non-null object
# area             2243 non-null float64
# baths            2243 non-null float64
# beds             2243 non-null float64
# building type    2243 non-null object
# latitude         2243 non-null float64
# longitude        2243 non-null float64
# neighborhood     2243 non-null object
# price            2243 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 175.2+ KB

# %%
que = que.drop(que[que['latitude'] < 35].index)
que.plot(kind="scatter", x='longitude', y='latitude')

# %%
que = que.drop(que[que['latitude'] < 40.5].index)
que.plot(kind="scatter", x='longitude', y='latitude')

# %%
que = que.drop(que[que['longitude'] < -74].index)
que.plot(kind="scatter", x='longitude', y='latitude')

# %% [markdown]
# *Now, **THIS** looks like Queens!*

# %%
que.neighborhood.unique()
# Out:
# array(['Hunters Point', 'East Elmhurst', 'Jackson Heights', 'Bayside',
#        'Auburndale', 'Middle Village', 'Forest Hills', 'Astoria',
#        'Glendale', 'Rego Park', 'Briarwood', 'Queensboro Hill',
#        'Woodhaven', 'South Jamaica', 'Elmhurst', 'Little Neck',
#        'Kew Gardens', 'Whitestone', 'Ridgewood', 'Arverne',
#        'Bay Terrace (Queens)', 'Kew Gardens Hills', 'Rockaway All',
#        'Richmond Hill', 'Far Rockaway', 'Jamaica Estates', 'Woodside',
#        'Springfield Gardens', 'Jamaica', 'Murray Hill (Queens)',
#        'Flushing', 'Beechhurst', 'Hammels', 'North Corona',
#        'Old Howard Beach', 'Sunnyside', 'St. Albans', 'South Ozone Park',
#        'Queens Village', 'Brookville', 'Cambria Heights', 'Rockwood Park',
#        'Bellerose', 'College Point', 'Long Island City', 'Clearview',
#        'Oakland Gardens', 'Pomonok', 'Jamaica Hills', 'Corona', 'Rosedale',
#        'East Flushing', 'Ozone Park', 'Douglaston', 'Lindenwood',
# ...

# %%
que.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2237 entries, 0 to 4911
# Data columns (total 9 columns):
# address          2237 non-null object
# area             2237 non-null float64
# baths            2237 non-null float64
# beds             2237 non-null float64
# building type    2237 non-null object
# latitude         2237 non-null float64
# longitude        2237 non-null float64
# neighborhood     2237 non-null object
# price            2237 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 174.8+ KB

# %%
que.to_csv('Queens_P.csv', index=False)

# %%
brx = pd.read_csv('Bronx.csv')
brx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225 entries, 0 to 1224
# Data columns (total 9 columns):
# address          1221 non-null object
# area             870 non-null float64
# baths            1097 non-null float64
# beds             1159 non-null float64
# building type    1217 non-null object
# latitude         1221 non-null float64
# longitude        1221 non-null float64
# neighborhood     1217 non-null object
# price            1221 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 86.2+ KB

# %%
brx = brx.dropna(how='any')
brx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 754 entries, 1 to 1221
# Data columns (total 9 columns):
# address          754 non-null object
# area             754 non-null float64
# baths            754 non-null float64
# beds             754 non-null float64
# building type    754 non-null object
# latitude         754 non-null float64
# longitude        754 non-null float64
# neighborhood     754 non-null object
# price            754 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 58.9+ KB

# %%
brx.plot(kind="scatter", x='longitude', y='latitude')

# %%
brx = brx.drop(brx[brx['latitude'] < 40.75].index)
brx.plot(kind="scatter", x='longitude', y='latitude')

# %%
brx.neighborhood.unique()
# Out:
# array(['Spuyten Duyvil', 'Wakefield', 'University Heights', 'Van Nest',
#        'Riverdale', 'Fieldston', 'Country Club', 'Throgs Neck', 'Bronx',
#        'Bronxdale', 'Bedford Park', 'Laconia', 'Bronxwood', 'Parkchester',
#        'Soundview', 'Highbridge', 'Castle Hill', 'Kingsbridge Heights',
#        'Edenwald', 'Morris Heights', 'Schuylerville', 'East Tremont',
#        'Williamsbridge', 'Morris Park', 'Baychester',
#        'Westchester Village', 'Pelham Parkway', 'Concourse', 'Woodlawn',
#        'Pelham Gardens', 'Co-op City', 'Pelham Bay', 'City Island',
#        'Hunts Point', 'Locust Point', 'Longwood', 'Fordham', 'Norwood',
#        'Crotona Park East', 'Eastchester', 'Woodstock', 'Kingsbridge',
#        'Morrisania', 'Mt. Hope', 'Claremont', 'North New York'], dtype=object)

# %%
brx.to_csv('Bronx_P.csv', index=False)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
man.hist(bins=50, figsize=(20,15))
plt.show()

# %%
from pandas.plotting import scatter_matrix as scatt
attr = ['beds', 'baths', 'area', 'neighborhood', 'price']
scatt(man[attr], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000116A8320>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000128BC2B0>]], dtype=object)

# %%
scatt(brx[attr], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000013268358>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013E74710>]], dtype=object)

# %%
scatt(que[attr], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001450FCF8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001552B8D0>]], dtype=object)

# %%
man = pd.read_csv('clean_data/Man_P.csv')
brx = pd.read_csv('clean_data/Bronx_P.csv')
br = pd.read_csv('clean_data/Brooklyn_P.csv')
staten = pd.read_csv('clean_data/Staten.csv')
que = pd.read_csv('clean_data/Queens_P.csv')

# %%
man['borough'] = 'manhattan'
man.head()
# Out:
#                      address    area  baths  beds building type   latitude  \
# 0        56 Walker Street #2  2670.0    3.5   3.0         Condo  40.719002
# 1   201 East 62nd Street #5A  2240.0    3.5   3.0         Co-op  40.763500
# 2    333 West 56th Street #2   820.0    1.0   1.0         Condo  40.766998
# 3  330 East 38th Street #20P   884.0    1.5   1.0         Condo  40.746300
# 4  322 West 57th Street #55U  1599.0    2.0   2.0         Condo  40.766800
#
#    longitude    neighborhood      price    borough
# 0 -74.003197         Tribeca  5600000.0  manhattan
# 1 -73.964798      Lenox Hill  2595000.0  manhattan
# 2 -73.984901  Hell's Kitchen   995000.0  manhattan
# 3 -73.972702     Murray Hill  1225000.0  manhattan
# 4 -73.984200  Hell's Kitchen  4595000.0  manhattan

# %%
brx['borough'] = 'bronx'
br['borough'] = 'brooklyn'
staten['borough'] = 'staten_island'
que['borough'] = 'queens'

df = pd.concat([man, brx, br, staten, que])
df
# Out:
#                                    address    area  baths  beds building type  \
# 0                      56 Walker Street #2  2670.0    3.5   3.0         Condo
# 1                 201 East 62nd Street #5A  2240.0    3.5   3.0         Co-op
# 2                  333 West 56th Street #2   820.0    1.0   1.0         Condo
# 3                330 East 38th Street #20P   884.0    1.5   1.0         Condo
# 4                322 West 57th Street #55U  1599.0    2.0   2.0         Condo
# 5                    408 Eighth Avenue #3C   712.0    1.0   1.0         Condo
# 6                151 East 85th Street #12H  1646.0    2.5   2.0         Condo
# 7                       30 Park Place #48B  1664.0    2.5   2.0         Condo
# 8                 438 East 12th Street #5R  1604.0    3.0   3.0         Condo
# 9               80 Riverside Boulevard #9P  1850.0    3.0   3.0         Condo
# 10                330 East 38th Street #7J   903.0    1.0   1.0         Condo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15300 entries, 0 to 2236
# Data columns (total 10 columns):
# address          15300 non-null object
# area             15300 non-null float64
# baths            15300 non-null float64
# beds             15300 non-null float64
# building type    15300 non-null object
# latitude         15300 non-null float64
# longitude        15300 non-null float64
# neighborhood     15300 non-null object
# price            15300 non-null float64
# borough          15300 non-null object
# dtypes: float64(6), object(4)
# memory usage: 1.3+ MB

# %% [markdown]
# Something's not right...

# %%
df = pd.concat([man, brx, br, staten, que], ignore_index=True)
df
# Out:
#                                     address    area  baths  beds  \
# 0                       56 Walker Street #2  2670.0    3.5   3.0
# 1                  201 East 62nd Street #5A  2240.0    3.5   3.0
# 2                   333 West 56th Street #2   820.0    1.0   1.0
# 3                 330 East 38th Street #20P   884.0    1.5   1.0
# 4                 322 West 57th Street #55U  1599.0    2.0   2.0
# 5                     408 Eighth Avenue #3C   712.0    1.0   1.0
# 6                 151 East 85th Street #12H  1646.0    2.5   2.0
# 7                        30 Park Place #48B  1664.0    2.5   2.0
# 8                  438 East 12th Street #5R  1604.0    3.0   3.0
# 9                80 Riverside Boulevard #9P  1850.0    3.0   3.0
# 10                 330 East 38th Street #7J   903.0    1.0   1.0
# 11                 205 West End Avenue #10M   900.0    1.0   1.0
# 12                       161 Maiden Ln #37A  1311.0    2.0   2.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15300 entries, 0 to 15299
# Data columns (total 10 columns):
# address          15300 non-null object
# area             15300 non-null float64
# baths            15300 non-null float64
# beds             15300 non-null float64
# building type    15300 non-null object
# latitude         15300 non-null float64
# longitude        15300 non-null float64
# neighborhood     15300 non-null object
# price            15300 non-null float64
# borough          15300 non-null object
# dtypes: float64(6), object(4)
# memory usage: 1.2+ MB

# %%
df.to_csv('data.csv', index=False)

# %% [markdown]
# Kernel died

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15300 entries, 0 to 15299
# Data columns (total 10 columns):
# address          15300 non-null object
# area             15300 non-null float64
# baths            15300 non-null float64
# beds             15300 non-null float64
# building type    15300 non-null object
# latitude         15300 non-null float64
# longitude        15300 non-null float64
# neighborhood     15300 non-null object
# price            15300 non-null float64
# borough          15300 non-null object
# dtypes: float64(6), object(4)
# memory usage: 1.2+ MB

# %%
df.hist(bins=50, figsize=(18,12))
plt.show()

# %%
df.plot(kind="scatter", x='longitude', y='latitude', figsize=(15, 12), alpha=0.1)

# %% [markdown]
# ***This indicates that most of the real-estate action is in Manhattan, North of Flatbush, Brighton & Manhattan Beaches all in Brooklyn, Forest Hills in Queens, and in the area of The Bronx that's close to Yonkers***

# %%
df['price'].min()
# Out:
# 44500.0

# %%
df.plot(kind="scatter", x='longitude', y='latitude', alpha=0.1, label='Price', c=df['price']/df['area'], s=df['price']/(df['area']*200), figsize=(18,15), cmap=plt.get_cmap("jet"), colorbar=True)
plt.legend()

# %%
df[(df['latitude'] > 40.9) & (df['longitude'] > -73.8)]
# Out:
# Empty DataFrame
# Columns: [address, area, baths, beds, building type, latitude, longitude, neighborhood, price, borough]
# Index: []

# %%
corr = df.corr()
corr['price'].sort_values(ascending=True)
# Out:
# longitude   -0.218191
# latitude     0.100576
# area         0.146168
# beds         0.293558
# baths        0.561574
# price        1.000000
# Name: price, dtype: float64

# %% [markdown]
# ***Working with what I have, is it possible to generate an attribute based on a combination of lat & long?***
#
# ***How can I implement publicly available data like distance from waterfront?***
#
# This perhaps? https://stackoverflow.com/questions/27697504/ocean-latitude-longitude-point-distance-from-shore

# %%
from pandas.plotting import scatter_matrix as scatt
attr = ['beds', 'baths', 'area', 'price']
scatt(df[attr], figsize=(15, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000A94A400>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000013104470>]], dtype=object)

# %%
# ts = pd.Series(df['Value'].values, index=df['Date'])
df['pricearea'] = df['price'].values/df['area'].values
df.head()
# Out:
#                      address    area  baths  beds building type   latitude  \
# 0        56 Walker Street #2  2670.0    3.5   3.0         Condo  40.719002
# 1   201 East 62nd Street #5A  2240.0    3.5   3.0         Co-op  40.763500
# 2    333 West 56th Street #2   820.0    1.0   1.0         Condo  40.766998
# 3  330 East 38th Street #20P   884.0    1.5   1.0         Condo  40.746300
# 4  322 West 57th Street #55U  1599.0    2.0   2.0         Condo  40.766800
#
#    longitude    neighborhood      price    borough    pricearea
# 0 -74.003197         Tribeca  5600000.0  manhattan  2097.378277
# 1 -73.964798      Lenox Hill  2595000.0  manhattan  1158.482143
# 2 -73.984901  Hell's Kitchen   995000.0  manhattan  1213.414634
# 3 -73.972702     Murray Hill  1225000.0  manhattan  1385.746606
# 4 -73.984200  Hell's Kitchen  4595000.0  manhattan  2873.671044

# %%
df['pricearea'].max() # I found this row had an invalid value of 1 for square area in a deleted cell...
# Out:
# 1390000.0

# %%
df[df['pricearea'] == 1390000].index
# Out:
# Int64Index([7204], dtype='int64')

# %%
df = df.drop(7204)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15299 entries, 0 to 15299
# Data columns (total 11 columns):
# address          15299 non-null object
# area             15299 non-null float64
# baths            15299 non-null float64
# beds             15299 non-null float64
# building type    15299 non-null object
# latitude         15299 non-null float64
# longitude        15299 non-null float64
# neighborhood     15299 non-null object
# price            15299 non-null float64
# borough          15299 non-null object
# pricearea        15299 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %%
df['pricearea'].describe()
# Out:
# count    15299.000000
# mean      1368.025028
# std        968.602782
# min          1.000000
# 25%        638.013594
# 50%       1205.287714
# 75%       1848.127908
# max      10184.716599
# Name: pricearea, dtype: float64

# %%
df[df['pricearea'] < 50]
# Out:
#                         address      area  baths  beds building type  \
# 139    211 East 53rd Street #2F  735000.0    1.0   1.0        Condop
# 12845     86 Rolling Hill Green   18803.0    1.5   3.0         House
# 14411        13-65 Eggert Place   14452.0    2.0   6.0  Multi-family
#
#         latitude  longitude  neighborhood     price        borough  pricearea
# 139    40.757599 -73.968597  Sutton Place  735000.0      manhattan   1.000000
# 12845  40.551102 -74.191803      Huguenot  437999.0  staten_island  23.294102
# 14411  40.608101 -73.759499  Far Rockaway  650000.0         queens  44.976474

# %% [markdown]
# ***Row 139 looks somewhat suspicious... A Condo apartment with a price per square area of exactly 1? Most likely a data entry error...***

# %%
df = df.drop(139)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15298 entries, 0 to 15299
# Data columns (total 11 columns):
# address          15298 non-null object
# area             15298 non-null float64
# baths            15298 non-null float64
# beds             15298 non-null float64
# building type    15298 non-null object
# latitude         15298 non-null float64
# longitude        15298 non-null float64
# neighborhood     15298 non-null object
# price            15298 non-null float64
# borough          15298 non-null object
# pricearea        15298 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %%
df['building type'].describe()
# Out:
# count     15298
# unique       10
# top       Condo
# freq       9044
# Name: building type, dtype: object

# %%
attr = ['beds', 'baths', 'area', 'price']
scatt(df[attr], figsize=(15, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001BB7C5C0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001DA8F198>]], dtype=object)

# %%
attr = ['beds', 'baths', 'area', 'pricearea']
scatt(df[attr], figsize=(15, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001ED21320>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FBC1470>]], dtype=object)

# %%
import seaborn as sns
sns.boxplot(x='building type', y='price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-39477e25fcae> in <module>()
#       1 import seaborn as sns
#       2
# ----> 3 sns.boxplot(x='building type', y='price')
#
# C:\Users\Laolu\Anaconda2\envs\py27\lib\site-packages\seaborn\categorical.pyc in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2173     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2174                           orient, color, palette, saturation,
# -> 2175                           width, fliersize, linewidth)
#    2176
#    2177     if ax is None:
#
# C:\Users\Laolu\Anaconda2\envs\py27\lib\site-packages\seaborn\categorical.pyc in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, fliersize, linewidth)
# ...

# %%
df = df.rename(columns={'building type': 'buildingtype'}) # This didn't make a difference; the problem was the data argument was missing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15298 entries, 0 to 15299
# Data columns (total 11 columns):
# address         15298 non-null object
# area            15298 non-null float64
# baths           15298 non-null float64
# beds            15298 non-null float64
# buildingtype    15298 non-null object
# latitude        15298 non-null float64
# longitude       15298 non-null float64
# neighborhood    15298 non-null object
# price           15298 non-null float64
# borough         15298 non-null object
# pricearea       15298 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %%
sns.boxplot(x='buildingtype', y='price', data=df)

# %% [markdown]
# **Quite a number of outliers... RobustScaler it is...**
#
# **Is there an efficient way to find out if they're legit?**

# %%
df.buildingtype.value_counts()
# Out:
# Condo                  9044
# Co-op                  2866
# Multi-family           1462
# House                  1122
# Townhouse               431
# Condop                  272
# Building                 83
# Other type               16
# Single-Family Home        1
# Commercial Building       1
# Name: buildingtype, dtype: int64

# %% [markdown]
# **Looks like single-family home and commercial building will have little relevance in the model if any**

# %%
df.buildingtype.value_counts().plot(kind='bar')

# %% [markdown]
# ***What are the implications of having so many Condos in the data? How might this affect the model? I think it follows from simple logic that most living spaces for sale in NYC would be Condo apartments. So this is acceptable.***

# %%
df.to_csv('data.csv', index=False) # saving the frame to keep changes just in case the kernel crashes...

# %%
# %time

sns.boxplot(x='borough', y='price', data=df)
# Out:
# Wall time: 0 ns

# %% [markdown]
# **I want to view the boxplot of boroughs without Manhattan data...**

# %%
boros = [x for x in df.borough.unique() if x != 'manhattan']
boros
# Out:
# ['bronx', 'brooklyn', 'staten_island', 'queens']

# %%
df[df['borough'] == boros]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-137-d1f0c20e3672> in <module>()
# ----> 1 df[df['borough'] == boros]
#
# C:\Users\Laolu\Anaconda2\envs\py27\lib\site-packages\pandas\core\ops.pyc in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# C:\Users\Laolu\Anaconda2\envs\py27\lib\site-packages\pandas\core\ops.pyc in na_op(x, y)
#     763
#     764         if is_object_dtype(x.dtype):
# --> 765             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     766         else:
#     767
#
# C:\Users\Laolu\Anaconda2\envs\py27\lib\site-packages\pandas\core\ops.pyc in _comp_method_OBJECT_ARRAY(op, x, y)
#     741             y = y.values
# ...

# %%
df_boros = df[df['borough'] != 'manhattan']
df_boros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7528 entries, 7772 to 15299
# Data columns (total 11 columns):
# address         7528 non-null object
# area            7528 non-null float64
# baths           7528 non-null float64
# beds            7528 non-null float64
# buildingtype    7528 non-null object
# latitude        7528 non-null float64
# longitude       7528 non-null float64
# neighborhood    7528 non-null object
# price           7528 non-null float64
# borough         7528 non-null object
# pricearea       7528 non-null float64
# dtypes: float64(7), object(4)
# memory usage: 705.8+ KB

# %%
sns.boxplot(x='borough', y='price', data=df_boros)

# %%
df_boros.buildingtype.value_counts()
# Out:
# Condo                  3192
# Co-op                  1420
# Multi-family           1330
# House                  1121
# Townhouse               262
# Condop                  122
# Building                 68
# Other type               11
# Single-Family Home        1
# Commercial Building       1
# Name: buildingtype, dtype: int64

# %% [markdown]
# ** I will eventually have to convert my categorical attributes to a numerical scale (integers) for successful ML...**
#
# I may also have to use StandardScaler to transform my data during feature scaling so that my outcomes are not affected by these crazy outliers...

# %%
# I'll have to run this again after converting categorical features...

corr_matrix = df.corr()
corr_matrix['price'].sort_values(ascending=True)
# Out:
# longitude   -0.218206
# latitude     0.100591
# beds         0.293536
# area         0.528461
# baths        0.561565
# pricearea    0.742735
# price        1.000000
# Name: price, dtype: float64

# %% [markdown]
# ***Let's get started on computing distance from shoreline using R...***

# %%
# %time

print len(df.neighborhood.unique())
len(df.buildingtype.unique())
# Out:
# Wall time: 0 ns
# 285
# 10

# %% [markdown]
# **We have 285 unique neighborhoods & 10 unique building types. What relevance will neighborhood have to the accuracy of our model? Some neighborhoods will definitely be highbrow and thus command higher price... What's the best way to encode the data in this column? Dummy variables? One-hot encoding?**
