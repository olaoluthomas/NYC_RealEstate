# %% [markdown]
# ***First time using R with Jupyter; first time using R in months... This should be fun...***

# %%
installed.packages()
# Out:
#              Package      LibPath                                      Version
# assertthat   assertthat   C:/Users/Laolu/Anaconda2/envs/py27/R/library 0.1
# backports    backports    C:/Users/Laolu/Anaconda2/envs/py27/R/library 1.0.4
# base         base         C:/Users/Laolu/Anaconda2/envs/py27/R/library 3.3.2
# base64enc    base64enc    C:/Users/Laolu/Anaconda2/envs/py27/R/library 0.1-3
# BH           BH           C:/Users/Laolu/Anaconda2/envs/py27/R/library 1.62.0-1
# bitops       bitops       C:/Users/Laolu/Anaconda2/envs/py27/R/library 1.0-6
# boot         boot         C:/Users/Laolu/Anaconda2/envs/py27/R/library 1.3-18
# broom        broom        C:/Users/Laolu/Anaconda2/envs/py27/R/library 0.4.1
# car          car          C:/Users/Laolu/Anaconda2/envs/py27/R/library 2.1-4
# caret        caret        C:/Users/Laolu/Anaconda2/envs/py27/R/library 6.0-73
# caTools      caTools      C:/Users/Laolu/Anaconda2/envs/py27/R/library 1.17.1
# ...

# %%
library(dplyr)
